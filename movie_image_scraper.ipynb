# %% [markdown]
# # project steps:
# 2. finish a download of an image
# 2. find the location of image inside a webpage
# 3. request image link and download
# 4. using for loop download it
# 5. Using link to find the high resolution version of images
# 6. multiple pages image download

# %% [markdown]
# 在macOS系统中，文件夹和文件名使用正斜线 ( / ) 进行分隔。
#
# 需要注意的是，macOS系统中，没有盘符的概念，所有的路径都是从根目录（ / ） 开始。

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# # 文件的操作:
#     ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ```使用open()打开，以只读的方式，打开名字为products的文本文件，并赋值给f
# f = open("/Users/yequ/products.txt", "r")
# ```

# %%
# TODO 使用open()打开，以只读的方式，名字为products的文本文件，并赋值给f
file_path = "/Users/yequ/products.txt"
f = open(file_path,"r")

# 使用read()函数读文件，并输出文件内容
print(f.read())

# 使用close()关闭文件
f.close()

# %%
# 使用open()以写入的方式，打开名字为products的文本文件，并赋值给f
f = open("/Users/yequ/products.txt", "w")
#w:如果该文件已存在则覆盖，不存在就创建新文件再写入。

# 使用write()函数在文档中写入
# “编号:4155047,价格:25.90,奥利奥（Oreo）巧克力味夹心饼干”
f.write("编号:4155047,价格:25.90,奥利奥（Oreo）巧克力味夹心饼干")

# 使用close()关闭文件
f.close()

# 使用open()以只读的方式，打开products文本文件，并赋值给newfile
newfile = open("/Users/yequ/products.txt", "r")

# 使用read()函数读文件，并输出文件内容
print(newfile.read())

# 使用close()关闭文件
newfile.close()

# %% [markdown]
# 使用open()函数打开文件操作完成之后，都需要使用close()来关闭文件，每次都这样有点繁琐。
#
# 这里可以使用with语句打开文件，with语句内的代码块执行完毕后会自动调用文件的close()函数。
#
# with语句配合as关键字，可以将打开的文件赋值给变量f，便于调用函数读文件。具体写法如下。
# 使用with...as语句配合open()函数，以只写的方式打开products文本文件，使用write()函数在products文本中写入。
#
# "编号:4155047,价格:25.90,奥利奥（Oreo）巧克力味夹心饼干"

# %%
# 使用with语句以只读的方式，打开/Users/yequ/products.txt文件，并赋值给f 
with open("/Users/yequ/products.txt", "r") as f:

    # 使用read()函数读文件，并输出文件内容
    print(f.read())
    
    
# 使用with语句以只写的方式，打开"/Users/yequ/products.txt"文件，并赋值给f 
with open("/Users/yequ/products.txt", "w") as f:

    # 使用write()函数写入文件
    f.write("编号:4155047,价格:25.90,奥利奥（Oreo）巧克力味夹心饼干")

# %%
import requests
# 将User-Agent以字典键对形式赋值给headers
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}
def get_response(url, headers):
    response = requests.get(url, headers = headers)
    
    return response

# %%
url = "https://npbcz.files.wordpress.com/2020/09/2-2.jpg"
response = get_response(url, headers)
img = response.content

# %%
# 使用with...as以wb方式，打开名字为"/Users/图片.jpg"的文件，并赋值给f
with open("image1.jpg", "wb") as f:

    # 使用write()函数写入img
    f.write(img)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
# 使用from..import从bs4模块导入BeautifulSoup
from bs4 import BeautifulSoup

def get_soup_class(response, class_name):
    html = response.text
    soup = BeautifulSoup(html, "lxml")
    content = soup.find_call(class_=class_name)
    print(content)
    return content

# %%
print(response)
get_soup_class(response, "pic")
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 print(response)
# ----> 2 get_soup_class(response, "pic")
#
# Cell In[17], line 7, in get_soup_class(response, class_name)
#       5 html = response.text
#       6 soup = BeautifulSoup(html, "lxml")
# ----> 7 content = soup.find_call(class_=class_name)
#       8 print(content)
#       9 return content
#
# TypeError: 'NoneType' object is not callable
